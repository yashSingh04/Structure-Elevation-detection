# %%
# !python3 train.py --config configs/config.json
# Out:
# /home/nximish/miniconda3/envs/GeoSpa/lib/python3.7/site-packages/torchvision/transforms/transforms.py:330: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   "Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. "
# height dataset train:val split
# 8992 1122
# DATASET=(originalGRSS_seamCarving)__DOMAIN_ADAPT=(lossBalancing_segmentation(['refined_shadow', 'footprint'])_regression(['dsm']))
# {1, 2, 4, 7}
# {1, 2, 4, 7}
# {1, 2, 4}
# {1, 2, 4}
# {1, 2}
# epoch: 0
# 100%|█████████████████████████████████████████| 562/562 [08:02<00:00,  1.17it/s]
# validations
# 100%|███████████████████████████████████████| 1122/1122 [01:07<00:00, 16.53it/s]
# 4.816833177239447
# TASKS: ['dsm', 'refined_shadow', 'footprint']
# individualVLoss: [3.6141057694978254, 0.48153540563110575, 0.7211920021105153]
# WEIGHTS: [0.6814659252699228, 2.2748345332525375, 1.5985728323580664]
# ...
